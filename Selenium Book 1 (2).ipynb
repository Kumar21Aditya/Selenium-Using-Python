# %%
# Python program to demonstrate
# selenium

# import webdriver
from selenium import webdriver

# create webdriver object
driver = webdriver.Firefox()
# get google.co.in
driver.get("https://google.co.in")

# %%
# Python program to demonstrate 
# selenium 

# import webdriver 
from selenium import webdriver 

# create webdriver object 
driver = webdriver.Chrome() 

# get google.co.in 
driver.get("https://in.search.yahoo.com/search?fr=mcafee&type=E210IN885G0&p=selenium+python+tutorial")

# %%
# import webdriver
from selenium import webdriver
from selenium.webdriver.common.by import By

# create webdriver object
driver = webdriver.Firefox()


# get geeksforgeeks.org
driver.get("https://www.amazon.in/?tag=msndeskabkin-21&ref=pd_sl_7qhce485bd_e&adgrpid=1322714095756137&hvadid=82669897710514&hvnetw=o&hvqmt=e&hvbmt=be&hvdev=c&hvlocint=&hvlocphy=1669&hvtargid=kwd-82670512756912:loc-90&hydadcr=14453_2334184")

# get element
element = driver.find_element(By.ID, "twotabsearchtextbox")

# send keys
element.send_keys("apple")

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

driver = webdriver.Firefox()
driver.get("http://www.python.org")
assert "Python" in driver.title
elem = driver.find_element(By.NAME, "q")
elem.clear()
elem.send_keys("pycon")
elem.send_keys(Keys.RETURN)
assert "No results found." not in driver.page_source
driver.close()

# %%
# import webdriver
from selenium import webdriver
from selenium.webdriver.common.by import By

# create webdriver object
driver = webdriver.Firefox()


# get geeksforgeeks.org
driver.get("https://www.amazon.in/?tag=msndeskabkin-21&ref=pd_sl_7qhce485bd_e&adgrpid=1322714095756137&hvadid=82669897710514&hvnetw=o&hvqmt=e&hvbmt=be&hvdev=c&hvlocint=&hvlocphy=1669&hvtargid=kwd-82670512756912:loc-90&hydadcr=14453_2334184")

# get element
element = driver.find_element(By.ID, "twotabsearchtextbox")

# send keys
element.send_keys("apple")
# Out:
# There was an error managing firefox (error sending request for url (https://github.com/mozilla/geckodriver/releases/latest): error trying to connect: An existing connection was forcibly closed by the remote host. (os error 10054)); using driver found in the cache

# %%
# import webdriver
from selenium import webdriver
from selenium.webdriver.common.by import By

# create webdriver object
driver = webdriver.Chrome()


# get geeksforgeeks.org
driver.get("https://www.facebook.com/login.php/")
driver.find_element(By.ID, "email").send_keys("adityapupun535@gmail.com")
driver.find_element(By.ID, "pass").send_keys("aditya@2003")
driver.find_element(By.ID, "loginbutton").click()

# %% [raw]
# Locators
# 1.id
# 2.name
# 3.Linktext/Partial linktext
# 4.class
# 5.tag name
#
# Customized Locator
# 1.CSS Selector
#     1.tag and id
#     2.tag and class
#     3.tag and attribute
#     4.tag,class and attribute
# 2.Xpath
#     1.absolute x path
#     2.relative x path

# %%
#ID AND NAME Locators
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()

driver.get("https://demo.nopcommerce.com/")
driver.maximize_window()
#driver.find_element(By.ID,"small-searchterms").send_keys("lenovo")
driver.find_element(By.NAME,"q").send_keys("lenovo")
driver.quit()

# %%
#LINK_TEXT AND PARTIAL_LINK_TEXT
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()

driver.get("https://demo.nopcommerce.com/")
driver.maximize_window()
#driver.find_element(By.LINK_TEXT,"Apple MacBook Pro 13-inch").click()
driver.find_element(By.PARTIAL_LINK_TEXT,"Reg").click()

# %%
#CLASS_NAME AND TAG_NAME
from selenium import webdriver
from selenium.webdriver.common.by import By

driver=webdriver.Chrome()
driver.maximize_window()
driver.get("https://automationexercise.com/")
div=driver.find_element(By.CLASS_NAME,"col-sm-4")
child_elements = div.find_elements(By.XPATH, "./*")

# Print the number of child elements
print(len(child_elements))
#links=driver.find_element(By.TAG_NAME,"a")
#print(len(links))
# Out:
# 1

# %%
#CSS Selector(TAG AND ID COMBINATION)
from selenium import webdriver
from selenium.webdriver.common.by import By

driver=webdriver.Chrome()
driver.get("https://www.facebook.com/")
driver.maximize_window()

#tag and id(tagname#value of id)
#driver.find_element(By.CSS_SELECTOR,"input#email").send_keys("abc")
driver.find_element(By.CSS_SELECTOR,"#email").send_keys("abc")

#tagname is always optional so the above code are same

# %%
#CSS Selector(TAG AND CLASS COMBINATION)
#syntax=tagname.valueof the class
from selenium import webdriver
from selenium.webdriver.common.by import By

driver=webdriver.Chrome()
driver.get("https://www.facebook.com/")
driver.maximize_window()
#driver.find_element(By.CSS_SELECTOR,"input.inputtext").send_keys("abc")
driver.find_element(By.CSS_SELECTOR,".inputtext").send_keys("abc")

# %%
#CSS Selector(TAG AND ATTRIBUTE COMBINATION)
#tagname[attribute=value]
from selenium import webdriver
from selenium.webdriver.common.by import By

driver=webdriver.Chrome()
driver.get("https://www.facebook.com/")
driver.maximize_window()
driver.find_element(By.CSS_SELECTOR,"input[name=email]").send_keys("abc")

# %% [raw]
# XPATH
# 1.it is a syntax or language for finding any element on the webpage using XML path expression
# 2.it is used to  find location of element on webpage using html DOM structure
# 3.XPATH can be used to navigate through element and attributes in DOM
# 4.it is an address of element
#
# Types of XPATH
# 1.Absolute/full Xpath
# 2.Relative/Partial Xpath

# %% [raw]
# url=https://orangehrm.com/
# full xpath-/html/body/nav/div/div[2]/div[2]/ul/li[1]/a/button
# Relative xpath-//*[@id="navbarSupportedContent"]/div[2]/ul/li[1]/a/button

# %% [raw]
# Difference
# 1.Relative Xpath directly jump to the element on DOM
# 2.Absolute Xpath starts from root html node

# %% [raw]
# 2.Realtive xpath start with //
# 2.Absolute xpath start with /

# %% [raw]
# 3.Relative xpath we use attributes
# 3.Absolute xpath we use tags/nodes

# %% [raw]
# reasons to prefer relative xpath
# 1.if the developer introduce new xpath absolute xpath change
# 2.if location is change then absolute xpath broken
# 3.absolute xpath is unstable

# %% [raw]
# Xpath Options
# 1.and
# 2.or
# 3.contains()
# 4.starts.with()
# 5.text()

# %%
#Example of Absolute Xpath

from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()

driver.get("https://www.amazon.in/")
driver.maximize_window()

#absolute xpath
driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input").send_keys("Data Science Book")
driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input").click()

# %%
#Example of Relative Xpath
from bs4 import Beautifulsoup as bs
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()

driver.get("https://www.amazon.in/")
driver.maximize_window()

#relative xpath
driver.find_element(By.XPATH,"//*[@id='twotabsearchtextbox']").send_keys("satyam")
driver.find_element(By.XPATH,"//*[@id='nav-search-submit-button']").click()
driver.find_element(By.XPATH,"//*[@id='n/976442031']/span/a/span").click()

# %%
##OR with Xpath


from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()

driver.get("https://www.amazon.in/")
driver.maximize_window()

#relative xpath
driver.find_element(By.XPATH,"//input[@id='twotabsearchtextbox' or @placeholder='twotabseartbox']").send_keys("data science")
#place holder value is the wrong value

# %%
#AND with Xpath

from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()

driver.get("https://www.amazon.in/")
driver.maximize_window()

#relative xpath
driver.find_element(By.XPATH,"//input[@id='twotabsearchtextbox' and @spellcheck='false']").send_keys("data science")

# %% [raw]
# #Xpath with contains()
# if a botton have start and stop both id
# then x path will be -//*[contains(@id,st)]#st is the common
# #xpath with starts_with
# xpath will be- //*[starts-with(@id,'st')]
# #xpath with or
# xpath will be-//*[@id='start' or @id='stop']

# %%
#xpath with contains
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()

driver.get("https://www.amazon.in/")
driver.maximize_window()

#relative xpath
driver.find_element(By.XPATH,"//input[contains(@id,'search')]").send_keys("data science")

# %%
#xpath with starts-with
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()

driver.get("https://www.amazon.in/")
driver.maximize_window()

#relative xpath
driver.find_element(By.XPATH,"//input[starts-with(@spellcheck,'fal')]").send_keys("data science")

# %% [raw]
# xpath axes
# 1.self
# 2.parent
# 3.child
# 4.decendant
#
# 5.following
# 6.following-sibling
#
# 7.preceding
# 8.preciding-sibling

# %%
from IPython.display import Image
image_path = "C:/Users/adity/Downloads/WhatsApp Image 2023-11-24 at 10.50.01_79937327.jpg" 
Image(filename=image_path)

# %%
from IPython.display import Image
image_path = "C:/Users/adity/Downloads/Screenshot 2023-11-24 110951.png" 
Image(filename=image_path)

# %%
#self 
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()

driver.get("https://money.rediff.com/gainers/bse/daily/groupa")

#relative xpath
name=driver.find_element(By.XPATH,"//a[contains(text(),'Cipla')]/self::a").text
print(name)
# Out:
# Cipla

# %%
#parent
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()

driver.get("https://money.rediff.com/gainers/bse/daily/groupa")

#relative xpath
name=driver.find_element(By.XPATH,"//a[contains(text(),'Cipla')]/parent::td").text
print(name)
# Out:
# Cipla

# %%
#child
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()

driver.get("https://money.rediff.com/gainers/bse/daily/groupa")

#relative xpath
name=driver.find_element(By.XPATH,"//a[contains(text(),'Cipla')]/ancestor::tr/child::td").text
print(name)
# Out:
# Cipla

# %%
#child all values
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()

driver.get("https://money.rediff.com/gainers/bse/daily/groupa")

#relative xpath
names=driver.find_elements(By.XPATH,"//a[contains(text(),'Cipla')]/ancestor::tr/child::td")
print(names)
print(len(names))
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="400c9f44061756d7ba6f3de0357e10bc", element="4D792787CCDC008B0DC0BC50EA1CFA08_element_9")>, <selenium.webdriver.remote.webelement.WebElement (session="400c9f44061756d7ba6f3de0357e10bc", element="4D792787CCDC008B0DC0BC50EA1CFA08_element_10")>, <selenium.webdriver.remote.webelement.WebElement (session="400c9f44061756d7ba6f3de0357e10bc", element="4D792787CCDC008B0DC0BC50EA1CFA08_element_11")>, <selenium.webdriver.remote.webelement.WebElement (session="400c9f44061756d7ba6f3de0357e10bc", element="4D792787CCDC008B0DC0BC50EA1CFA08_element_12")>, <selenium.webdriver.remote.webelement.WebElement (session="400c9f44061756d7ba6f3de0357e10bc", element="4D792787CCDC008B0DC0BC50EA1CFA08_element_13")>]
# 5

# %%
#Ancestor
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()

driver.get("https://money.rediff.com/gainers/bse/daily/groupa")

#relative xpath
names=driver.find_element(By.XPATH,"//a[contains(text(),'Cipla')]/ancestor::tr").text
print(names)
# Out:
# Cipla A 1,168.60 1,198.35 + 2.55

# %%
#Descendant
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()

driver.get("https://money.rediff.com/gainers/bse/daily/groupa")

#relative xpath
names=driver.find_elements(By.XPATH,"//a[contains(text(),'Cipla')]/ancestor::tr/descendant::*")
print(len(names))
# Out:
# 7

# %%
#Following
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()

driver.get("https://money.rediff.com/gainers/bse/daily/groupa")

names=driver.find_elements(By.XPATH,"//a[contains(text(),'Cipla')]/ancestor::tr/following::*")
print(len(names))
# Out:
# 2545

# %%
#following sibling
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()

driver.get("https://money.rediff.com/gainers/bse/daily/groupa")

names=driver.find_elements(By.XPATH,"//a[contains(text(),'Cipla')]/ancestor::tr/following-sibling::tr")
print(len(names))
# Out:
# 288

# %%
#Preceding
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()

driver.get("https://money.rediff.com/gainers/bse/daily/groupa")

names=driver.find_elements(By.XPATH,"//a[contains(text(),'Cipla')]/ancestor::tr/preceding::*")
print(len(names))
# Out:
# 589

# %%
#preceding-sibling
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()

driver.get("https://money.rediff.com/gainers/bse/daily/groupa")

names=driver.find_elements(By.XPATH,"//a[contains(text(),'Cipla')]/ancestor::tr/preceding-sibling::*")
print(len(names))
# Out:
# 49
