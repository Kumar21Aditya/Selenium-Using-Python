# %% [raw]
# 1.Application command
# 2.Conditional command
# 3.browser command
# 4.navigational command
# 5.wait command

# %% [raw]
# Application command
# 1.title
# 2.current_url
# 3.page_source
# 4.get()

# %%
#title
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://money.rediff.com/gainers/bse/daily/groupa")
print(driver.title)
# Out:
# Daily Gainers: BSE, NSE, Stock quotes, share market, stock market, stock tips: Rediff Stocks

# %%
#currect_url
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://money.rediff.com/gainers/bse/daily/groupa")
print(driver.current_url)
driver.quit()
# Out:
# https://money.rediff.com/gainers/bse/daily/groupa

# %%
#page_source
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://money.rediff.com/gainers/bse/daily/groupa")
print(driver.page_source)
# Out:
# <html><head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title>Daily Gainers: BSE, NSE, Stock quotes, share market, stock market, stock tips: Rediff Stocks</title>
# <meta name="keywords" content="Rediff.com, BSE, NSE, Stocks, Get quote, Advertise">
# <meta name="author" content="Rediff MoneyWiz">
# <meta name="Description" content="Daily Gainers in stock market - Rediff MoneyWiz, the personal finance service from Rediff.com equips the user with tools and information in the form of graphs, charts, expert advice, and more to stay up-to-date and make informed decisions.">
# <meta name="viewport" content="width=990">
# <meta name="DC.creator" content="Rediff MoneyWiz - //money.rediff.com">
# <meta name="DC.subject" content="Stock prices, charts, news, and more">
# <meta name="robots" content="index, follow">
# <meta name="revisit-after" content="1 day">
# <meta http-equiv="imagetoolbar" content="false">
# ...

# %% [raw]
# conditional command
# 1.is_displayed()
# 2.is_enabled()
# 3.is_selected()

# %%
#is_displayed() and is_enabled()
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://demo.nopcommerce.com/register?returnUrl=%2F")
searchbox=driver.find_element(By.XPATH,"//*[@id='small-searchterms']")
print(searchbox.is_displayed())
print(searchbox.is_enabled())
# Out:
# True
# True

# %%
#is_selected()
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://demo.nopcommerce.com/register?returnUrl=%2F")
checkbox=driver.find_element(By.XPATH,"//*[@id='gender-male']")
print(checkbox.is_selected())
# Out:
# False

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://demo.nopcommerce.com/register?returnUrl=%2F")
checkbox=driver.find_element(By.XPATH,"//*[@id='gender-male']")
print(checkbox.is_selected())
checkbox.click()
# Out:
# False

# %% [raw]
# Browser command
# 1.close()#after closing other program will run behind
# 2.quit()#both close browser as well as all operations behind  and kill all process

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://opensource-demo.orangehrmlive.com/")
driver.find_element(By.CLASS_NAME,"oxd-icon").click()
driver.close()

# %% [markdown]
# navigational command
# 1.back()
# 2.forward()
# 3.refresh()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://www.snapdeal.com/")
driver.get("https://www.amazon.in/")
driver.back()
driver.forward()
driver.refresh()
driver.quit()

# %%
#find_element vs find_elements
#find_element-return single first element

# %% [raw]
# CASE1.Locator Matching with single web element

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://demo.nopcommerce.com/")
search=driver.find_element(By.XPATH,"//*[@id='small-searchterms']")
search.send_keys("apple macbook")

# %% [raw]
# CASE2.Locator Matching with multiple web element

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://demo.nopcommerce.com/")
element=driver.find_element(By.XPATH,"//div[@class='footer']//a")
element.text
# Out:
# 'Sitemap'

# %% [raw]
# CASE3:Element not available /no element exception

# %%
#Right link text value
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://demo.nopcommerce.com/")
element=driver.find_element(By.LINK_TEXT,"Log in").click()

# %%
#wrong link text value
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://demo.nopcommerce.com/")
element=driver.find_element(By.LINK_TEXT,"Log").click()#login to changed it to "log"
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[6], line 6
#       4 driver=webdriver.Chrome()
#       5 driver.get("https://demo.nopcommerce.com/")
# ----> 6 element=driver.find_element(By.LINK_TEXT,"Log").click()#login to changed it to "log"
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:741, in WebDriver.find_element(self, by, value)
#     738     by = By.CSS_SELECTOR
#     739     value = f'[name="{value}"]'
# --> 741 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
# ...

# %%
#find_elements()

# %% [raw]
# CASE1:Locator matching with single web element

# %%
#Right link text value
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://demo.nopcommerce.com/")
elements=driver.find_elements(By.XPATH,"//*[@id='small-searchterms']")#you can not spply semd_keys() because it gives output as list format
print(len(elements))
elements[0].send_keys("apple")
# Out:
# 1

# %% [raw]
# CASE2:Locator matching multiple web element

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://demo.nopcommerce.com/")
elements=driver.find_elements(By.XPATH,"//div[@class='footer']//a")
for i in elements:
    print(i.text)
# Out:
# Sitemap
# Shipping & returns
# Privacy notice
# Conditions of Use
# About us
# Contact us
# Search
# News
# Blog
# Recently viewed products
# Compare products list
# New products
# My account
# Orders
# Addresses
# Shopping cart
# Wishlist
# Apply for vendor account
# Facebook
# Twitter
# RSS
# YouTube
# nopCommerce

# %% [raw]
# CASE3:element not available and the throw nosuchElementException

# %%
#perfect match
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://demo.nopcommerce.com/")
elements=driver.find_elements(By.LINK_TEXT,"Apple MacBook Pro 13-inch")
print(len(elements))
elements[0].click()
# Out:
# 1

# %%
#wrong LINK_TEXT VALUE
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://demo.nopcommerce.com/")
elements=driver.find_elements(By.LINK_TEXT,"Apple MacBook ")
len(elements)#elements are not available so it return 0
# Out:
# 0

# %% [raw]
# text vs get_attribute('values')

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://demo.nopcommerce.com/login?returnUrl=%2F")
email_box=driver.find_element(By.XPATH,"//*[@id='Email']")
email_box.clear()
email_box.send_keys("aaa@gmail.com")
print("tesult of text" ,email_box.text)#it will not showing because there is no inner text
print("result of get_attribute('value,)",email_box.get_attribute('value'))
# Out:
# tesult of text
# result of get_attribute('value,) aaa@gmail.com

# %% [raw]
# wait commands
# -------------
# time.sleep(time)
# --------------
# 1.implicit wait
# 2.explicit wait

# %% [raw]
# sleep()

# %% [raw]
# adv:
#    1.easy to use
# disadv:
#     1.performance is poor
#     2.if the element is not available within the time mentioned ,still there is getting chance of exception

# %%
#python sleep
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://www.google.co.in/")
driver.maximize_window()
searchbox=driver.find_element(By.XPATH,"//*[@id='APjFqb']")
searchbox.send_keys("Selenium")
searchbox.submit()
import time
time.sleep(5)#after 5 minutes only it will perform next operation
driver.find_element(By.XPATH,"//*[@id='rso']/div[1]/div/div/div/div/div/div/div/div[1]/div/span/a/h3").click()#copying default xpath

# %%
#sleep()
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://www.google.co.in/")
driver.maximize_window()
searchbox=driver.find_element(By.XPATH,"//*[@id='APjFqb']")
searchbox.send_keys("Selenium")
searchbox.submit()
import time
time.sleep(5)#after 5 minutes only it will perform next operation
#problems:
#performance is poor
#if the element is not available within the time mentioned ,still there is getting chance of exception
driver.find_element(By.XPATH,"//h3[text()='Selenium']").click()#customize xpath

# %% [raw]
# implicit wait

# %% [markdown]
# Advantage:
# 1.single statement
# 2.performance will not be reduced
#  (if the element will available within time it proceed to execute further)
# Disadvantage:
# 1.if the element is not available within the time mentioned,still there is a chance of getting exception

# %%
#implicit wait
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.implicitly_wait(10)#10 second wait
#whereever synchronization problems occur,implicit wait will take care
#it will applicable for all the below statements
#default value of implicitely_wait is 0 sec
driver.get("https://www.google.co.in/")
x=driver.find_element(By.XPATH,"//*[@id='APjFqb']")
x.send_keys("Selenium")
x.submit()
driver.quit()

# %% [raw]
# explicit wait
# it works based on condition

# %%
adv:
  1.waiting is based on condition
  2.more effective
disadv:
    1.multiple places
    2.little bit difficulty

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC

driver=webdriver.Chrome()
driver.get("https://www.google.co.in/")

#declare explicitely wait
mywait=WebDriverWait(driver,10)#after 10 sec it execute next statement

driver.maximize_window()

searchbox=driver.find_element(By.XPATH,"//*[@id='APjFqb']")
searchbox.send_keys("Selenium")
searchbox.submit()

searchlink=mywait.until(EC.presence_of_element_located((By.XPATH,"//*[@id='rso']/div[1]/div/div/div/div/div/div/div/div[1]/div/span/a/h3")))
searchlink.click()

driver.quit()

# %%
#handling exceptions
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException, ElementNotVisibleException, ElementNotSelectableException

driver=webdriver.Chrome()
driver.get("https://www.google.co.in/")

#declare explicitely wait
mywait=WebDriverWait(driver,10,ignored_exceptions=[NoSuchElementException,ElementNotVisibleException,ElementNotSelectableException])#after 10 sec it execute next statement

driver.maximize_window()

searchbox=driver.find_element(By.XPATH,"//*[@id='APjFqb']")
searchbox.send_keys("Selenium")
searchbox.submit()

searchlink=mywait.until(EC.presence_of_element_located((By.XPATH,"//*[@id='rso']/div[1]/div/div/div/div/div/div/div/div[1]/div/span/a/h3")))
searchlink.click()

driver.quit()

# %%
#poll_frequency
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException, ElementNotVisibleException, ElementNotSelectableException

driver=webdriver.Chrome()
driver.get("https://www.google.co.in/")

#declare explicitely wait
mywait=WebDriverWait(driver,10,poll_frequency=2,ignored_exceptions=[NoSuchElementException,ElementNotVisibleException,ElementNotSelectableException])#after 10 sec it execute next statement
#poll frequency meand between 10 second ,in every 2 second it will check wheather element is found or not
#it makes faster
driver.maximize_window()

searchbox=driver.find_element(By.XPATH,"//*[@id='APjFqb']")
searchbox.send_keys("Selenium")
searchbox.submit()

searchlink=mywait.until(EC.presence_of_element_located((By.XPATH,"//*[@id='rso']/div[1]/div/div/div/div/div/div/div/div[1]/div/span/a/h3")))
searchlink.click()

driver.quit()

# %% [raw]
# Checkbox

# %%
#handling checkbox
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://www.rahulshettyacademy.com/AutomationPractice/")
driver.find_element(By.XPATH,"//*[@id='checkBoxOption1']").click()
driver.quit()

# %%
#handling checkbox
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://www.rahulshettyacademy.com/AutomationPractice/")
x=driver.find_elements(By.XPATH,"//input[@type='checkbox' and contains(@id,'Option')]")
print(len(x))
# Out:
# 3

# %%
#approach 1
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://www.rahulshettyacademy.com/AutomationPractice/")
x=driver.find_elements(By.XPATH,"//input[@type='checkbox' and contains(@id,'Option')]")
print(len(x))
for i in range(len(x)):
    x[i].click()
# Out:
# 3

# %%
#approach2
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://www.rahulshettyacademy.com/AutomationPractice/")
x=driver.find_elements(By.XPATH,"//input[@type='checkbox' and contains(@id,'Option')]")
print(len(x))
for i in x:
    i.click()
# Out:
# 3

# %%
#select multiple checkbox by choice
#approach2
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://www.rahulshettyacademy.com/AutomationPractice/")
checkboxes=driver.find_elements(By.XPATH,"//input[@type='checkbox' and contains(@id,'Option')]")
for i in checkboxes:
    name=i.get_attribute('id')
    if name=='checkBoxOption1' and name=='checkBoxOption3':
        i.click()

# %%
#select last 2 checkboxes
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://www.rahulshettyacademy.com/AutomationPractice/")
checkboxes=driver.find_elements(By.XPATH,"//input[@type='checkbox' and contains(@id,'Option')]")

for i in range(1,len(checkboxes)):
    checkboxes[i].click()

# %%
#select first 2 element

from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://www.rahulshettyacademy.com/AutomationPractice/")
checkboxes=driver.find_elements(By.XPATH,"//input[@type='checkbox' and contains(@id,'Option')]")

for i in range(len(checkboxes)):
    if i<2:
        checkboxes[i].click()

# %%
#clear all checkboxes
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://www.rahulshettyacademy.com/AutomationPractice/")
checkboxes=driver.find_elements(By.XPATH,"//input[@type='checkbox' and contains(@id,'Option')]")

for j in checkboxes:
    j.click()
time.sleep(5)    
for i in checkboxes:
    if i.is_selected():
        i.click()

# %% [raw]
# #Works with link
# 1.internal link(when click on link it will navigate to same page)
# 2.external link(navigate to different page)
# 3.broken link(will not have any target page)

# %%
#click on a link
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://demo.nopcommerce.com/")
driver.maximize_window()
driver.find_element(By.LINK_TEXT,"Jewelry").click()

# %%
#find  total no of links
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://demo.nopcommerce.com/")
driver.maximize_window()
print(len(links))
links=driver.find_elements(By.TAG_NAME,'a')
for i in links:
    print(i)
# Out:
# 90
# <selenium.webdriver.remote.webelement.WebElement (session="6749523b5cbfca50466fc005c1fb0408", element="CA94FB2868F9F5620F14F35BEC5113B0_element_53")>
# <selenium.webdriver.remote.webelement.WebElement (session="6749523b5cbfca50466fc005c1fb0408", element="CA94FB2868F9F5620F14F35BEC5113B0_element_56")>
# <selenium.webdriver.remote.webelement.WebElement (session="6749523b5cbfca50466fc005c1fb0408", element="CA94FB2868F9F5620F14F35BEC5113B0_element_59")>
# <selenium.webdriver.remote.webelement.WebElement (session="6749523b5cbfca50466fc005c1fb0408", element="CA94FB2868F9F5620F14F35BEC5113B0_element_63")>
# <selenium.webdriver.remote.webelement.WebElement (session="6749523b5cbfca50466fc005c1fb0408", element="CA94FB2868F9F5620F14F35BEC5113B0_element_68")>
# <selenium.webdriver.remote.webelement.WebElement (session="6749523b5cbfca50466fc005c1fb0408", element="CA94FB2868F9F5620F14F35BEC5113B0_element_78")>
# ...

# %%
#find  total no of links by Xpath
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://demo.nopcommerce.com/")
driver.maximize_window()
print(len(links))
links=driver.find_elements(By.XPATH,'//a')
for i in links:
    print(i.text)
# Out:
# 90
# Register
# Log in
# Wishlist (0)
# Shopping cart (0)
#
# Computers
#
#
#
# Electronics
#
#
#
# Apparel
#
#
#
# Digital downloads
# Books
# Jewelry
# Gift Cards
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1
# 2
# Documentation
# Forums
# nopCommerce.com
# Electronics
#
# Apparel
#
# Digital downloads
#
#
# Build your own computer
#
# Apple MacBook Pro 13-inch
#
# HTC One M8 Android L 5.0 Lollipop
#
# $25 Virtual Gift Card
# New online store is open!
# DETAILS
# nopCommerce new release!
# DETAILS
# About nopCommerce
# DETAILS
# View News Archive
# Sitemap
# Shipping & returns
# Privacy notice
# Conditions of Use
# About us
# Contact us
# Search
# News
# Blog
# Recently viewed products
# Compare products list
# New products
# My account
# Orders
# Addresses
# Shopping cart
# Wishlist
# Apply for vendor account
# Facebook
# Twitter
# RSS
# YouTube
# nopCommerce

# %%
#handle broken links
from selenium import webdriver
from selenium.webdriver.common.by import By
import requests

driver=webdriver.Chrome()
driver.get("http://www.deadlinkcity.com/")
driver.maximize_window()

links=driver.find_elements(By.TAG_NAME,'a')
count=0

for link in links:
    url=link.get_attribute('href')
    try:
        res=requests.head(url)
    except:
        None
    if res.status_code>=400:
        print(url,"is the broken link")
        count=count+1
    else:
        print(url,"is valid")
print(count)
# Out:
# http://www.deadlinkcity.com/comparison.asp is valid
# http://www.deadlinkcity.com/errorlist.asp is valid
# http://www.deadlinkcity.com/error-page.asp?e=400 is the broken link
# http://www.deadlinkcity.com/error-page.asp?e=401 is the broken link
# http://www.deadlinkcity.com/error-page.asp?e=402 is the broken link
# http://www.deadlinkcity.com/error-page.asp?e=403 is the broken link
# http://www.deadlinkcity.com/error-page.asp?e=404 is the broken link
# http://www.deadlinkcity.com/error-page.asp?e=405 is the broken link
# http://www.deadlinkcity.com/error-page.asp?e=406 is the broken link
# http://www.deadlinkcity.com/error-page.asp?e=407 is the broken link
# http://www.deadlinkcity.com/error-page.asp?e=408 is the broken link
# http://www.deadlinkcity.com/error-page.asp?e=409 is the broken link
# http://www.deadlinkcity.com/error-page.asp?e=410 is the broken link
# http://www.deadlinkcity.com/error-page.asp?e=411 is the broken link
# ...

# %% [raw]
# dropdown elemts handling

# %%
#approach-1
from selenium import webdriver
from selenium.webdriver.common.by import By
import requests

driver=webdriver.Chrome()
driver.get("https://demo.automationtesting.in/Register.html#google_vignette")
driver.find_element(By.XPATH,"//*[@id='Skills']").click()
driver.find_element(By.XPATH,"//*[@id='Skills']/option[4]").click()

# %%
#approach2
from selenium import webdriver
from selenium.webdriver.common.by import By
import requests
from selenium.webdriver.support.ui import Select


driver=webdriver.Chrome()
driver.get("https://demo.automationtesting.in/Register.html#google_vignette")
skill=driver.find_element(By.XPATH,"//*[@id='Skills']")
drpskill=Select(skill)
#Or drpskill=Select(driver.find_element(By.XPATH,"//*[@id='Skills']"))  

drpskill.select_by_visible_text("Analytics")
#or drpskill.select_by_value("10")#10 means the value of the tag
#drpskill.select_by_index(13)#13 is the index position

# %%
#capture all the options 
from selenium import webdriver
from selenium.webdriver.common.by import By
import requests
from selenium.webdriver.support.ui import Select


driver=webdriver.Chrome()
driver.get("https://demo.automationtesting.in/Register.html#google_vignette")
skill=driver.find_element(By.XPATH,"//*[@id='Skills']")
drpskill=Select(skill)

drpskill.select_by_visible_text("Analytics")
alloptions=drpskill.options
print(len(alloptions))
for i in alloptions:
    print(i.text)
# Out:
# 78
# Select Skills
# Adobe InDesign
# Adobe Photoshop
# Analytics
# Android
# APIs
# Art Design
# AutoCAD
# Backup Management
# C
# C++
# Certifications
# Client Server
# Client Support
# Configuration
# Content Managment
# Content Management Systems (CMS)
# Corel Draw
# Corel Word Perfect
# CSS
# Data Analytics
# Desktop Publishing
# Design
# Diagnostics
# Documentation
# End User Support
# Email
# Engineering
# Excel
# FileMaker Pro
# Fortran
# HTML
# Implementation
# Installation
# Internet
# iOS
# iPhone
# Linux
# Java
# Javascript
# Mac
# Matlab
# Maya
# Microsoft Excel
# Microsoft Office
# Microsoft Outlook
# Microsoft Publisher
# Microsoft Word
# Microsoft Visual
# Mobile
# MySQL
# Networks
# Open Source Software
# Oracle
# Perl
# PHP
# Presentations
# Processing
# Programming
# PT Modeler
# Python
# QuickBooks
# Ruby
# Shade
# Software
# Spreadsheet
# SQL
# Support
# Systems Administration
# Tech Support
# Troubleshooting
# Unix
# UI / UX
# Web Page Design
# Windows
# ...

# %%
#approach 3
from selenium import webdriver
from selenium.webdriver.common.by import By
import requests
from selenium.webdriver.support.ui import Select


driver=webdriver.Chrome()
driver.get("https://demo.automationtesting.in/Register.html#google_vignette")
drpskill=Select(driver.find_element(By.XPATH,"//*[@id='Skills']"))
options=drpskill.options
for i in options:
    if i.text=='Analytics':
        i.click()
